# %%
# Import the BatteryTestAnalyzer class
from battery_test_analyzer import BatteryTestAnalyzer

# %%
# Read the content of the data.csv file
with open('data.csv', 'r') as file:
    file_content = file.read()

# %%
# Instantiate the BatteryTestAnalyzer class
test_analyzer = BatteryTestAnalyzer(file_content)

# %%
# Plot the aggregations
test_analyzer.plot_aggregations()
